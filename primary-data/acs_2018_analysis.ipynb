# %% [markdown]
# ### Acs_2018 Data Analysis

# %% [markdown]
# ##### To analyze and see a relationship between college and undergraduate enrollment in public vs private and the predominant class in the area/neighborhood

# %%
# %%bigquery
# select i.ZCTA5, Predominant_Class , College_Undergrad_Public, College_Undergrad_Private
# from acs_2018_modeled.Income_Beam_DF i join acs_2018_modeled.PrivatePublic_School_Enrollment_Beam_DF s
# on i.ZCTA5 = s.ZCTA5
# where College_Undergrad_Public <> 0 and College_Undergrad_Private <> 0
# order by College_Undergrad_Private desc
# limit 20
# Out:
#     ZCTA5 Predominant_Class  College_Undergrad_Public  \
# 0   19104            Lowest                      2029
# 1   13210            Lowest                      2251
# 2   90007            Lowest                      2938
# 3   76706            Lowest                      1948
# 4   83440            Lowest                      2260
# 5   10027            Lowest                      2187
# 6   77004            Lowest                      5018
# 7   94305      Lower_Middle                      1716
# 8   46556            Lowest                       414
# 9   10458            Lowest                      3932
# 10  06511            Lowest                      1998
# 11  02120            Lowest                       470
# 12  01610            Lowest                      1764
# 13  60637            Lowest                      2128
# 14  01609            Lowest                      1351
# 15  21218            Lowest                      3112
# 16  30314            Lowest                      2693
# 17  72143            Middle                       812
# 18  24501            Lowest                       888
# 19  00926            Lowest                      2874
#
#     College_Undergrad_Private
# 0                       17773
# 1                       11614
# 2                        8817
# 3                        8433
# 4                        8213
# 5                        6654
# 6                        5810
# 7                        5520
# 8                        5312
# 9                        4457
# 10                       4397
# 11                       4222
# 12                       4110
# 13                       4080
# 14                       4053
# 15                       4004
# 16                       3948
# 17                       3883
# 18                       3810
# 19                       3807

# %% [markdown]
# ##### To count the number of each predominant class

# %%
# %%bigquery
# select count(Predominant_Class) as Count_of_class, Predominant_Class
# from acs_2018_modeled.Income_Beam_DF
# group by Predominant_Class
# order by Count_of_class desc
# Out:
#    Count_of_class Predominant_Class
# 0            3252            Lowest
# 1             642            Middle
# 2             627      Lower_Middle
# 3              39      Upper_Middle
# 4               4              Rich

# %% [markdown]
# ##### To check the relationship of housing ages and the housing value

# %%
# %%bigquery
# select b.*, High_Housing_Value
# from acs_2018_modeled.Built_Year_Beam_DF b join acs_2018_modeled.Housing_Value_Beam_DF h
# on b.ZCTA5 = h.ZCTA5
# where High_Housing_Value <> 0 and Middle_Housing_Value <> 0 and Low_Housing_Value <> 0
# order by High_Housing_Value desc
# limit 20
# Out:
#     ZCTA5  Built_2014_or_later  Built_2010_to_2013  Built_2000_to_2009  \
# 0   90402                  1.2                 1.3                 5.8
# 1   94024                  1.1                 1.8                 6.3
# 2   94957                  1.3                 4.8                 1.3
# 3   94127                  0.0                 0.2                 1.0
# 4   94087                  0.9                 0.4                 3.8
# 5   92625                  2.2                 2.1                10.2
# 6   22205                  1.2                 1.4                 4.9
# 7   95130                  0.2                 0.0                 3.4
# 8   02468                  0.0                 0.5                 1.3
# 9   02493                  0.2                 2.7                 8.8
# 10  96821                  0.7                 0.3                 9.0
# 11  95120                  0.7                 0.5                 2.9
# 12  92657                  1.3                 1.4                35.9
# 13  94070                  0.4                 0.3                 3.5
# 14  94402                  0.0                 1.5                 4.3
# 15  22182                  0.3                 1.3                12.5
# 16  94301                  1.1                 2.5                 7.0
# 17  94549                  2.0                 0.6                 5.0
# 18  92603                  0.0                 0.0                45.1
# 19  94506                  1.6                 2.8                15.1
#
#     Built_1990_to_1999  Built_1980_to_1989  Built_1970_to_1979  \
# 0                  6.9                 4.4                17.3
# 1                  5.9                 5.9                11.4
# 2                  6.6                 6.3                 6.3
# 3                  1.7                 2.4                 3.1
# 4                  4.9                 8.6                20.5
# 5                  9.4                 9.2                22.1
# 6                  1.9                 6.9                 4.2
# 7                  2.7                 4.5                17.0
# 8                  0.4                 1.3                 2.2
# 9                  8.7                 6.5                 7.3
# 10                 8.0                13.0                14.8
# 11                 9.9                19.6                37.6
# 12                51.4                 3.2                 3.7
# 13                 3.4                10.2                15.4
# 14                 4.4                 5.2                13.7
# 15                20.7                24.9                28.5
# 16                 7.5                 6.3                11.9
# 17                 6.0                10.2                15.8
# 18                14.6                12.2                21.0
# 19                41.9                33.5                 3.5
#
#     Built_1960_to_1969  Built_1950_to_1959  Built_1940_to_1949  \
# 0                  8.2                13.1                11.9
# 1                 18.9                37.5                 8.8
# 2                  2.8                21.0                 6.1
# 3                  8.7                16.6                11.3
# 4                 30.7                26.6                 2.6
# 5                 21.7                12.9                 7.2
# 6                  5.7                21.5                36.2
# 7                 37.5                33.0                 1.2
# 8                  1.2                20.6                11.3
# 9                 17.7                17.6                 4.0
# 10                20.9                25.6                 6.3
# 11                23.9                 2.0                 1.2
# 12                 0.7                 2.3                 0.0
# 13                15.6                21.8                20.3
# 14                11.8                21.6                16.1
# 15                 8.8                 1.7                 0.9
# 16                13.5                 8.6                 8.5
# 17                18.7                28.3                 9.7
# 18                 5.7                 1.3                 0.0
# 19                 0.4                 0.4                 0.5
#
#     Built_1939_or_before  High_Housing_Value
# 0                   29.8                98.7
# 1                    2.5                98.0
# 2                   43.5                97.7
# 3                   55.0                97.5
# 4                    1.0                97.3
# 5                    2.9                97.3
# 6                   16.1                97.2
# 7                    0.5                97.1
# 8                   61.3                97.1
# 9                   26.6                96.9
# 10                   1.5                96.9
# 11                   1.9                96.8
# 12                   0.0                96.8
# 13                   9.2                96.7
# 14                  21.4                96.6
# 15                   0.5                96.6
# 16                  33.2                96.5
# 17                   3.5                96.5
# 18                   0.1                96.4
# 19                   0.4                96.4

# %%
# %%bigquery
# select High_Housing_Value, count(Built_2014_or_later) as num_of_highvalue_built2014_or_later
# from acs_2018_modeled.Built_Year_Beam_DF b join acs_2018_modeled.Housing_Value_Beam_DF h
# on b.ZCTA5 = h.ZCTA5
# where High_Housing_Value <> 0 and Middle_Housing_Value <> 0 and Low_Housing_Value <> 0
# group by High_Housing_Value having High_Housing_Value > 50
# order by num_of_highvalue_built2014_or_later desc
# limit 20
# Out:
#     High_Housing_Value  num_of_highvalue_built2014_or_later
# 0                 51.7                                    8
# 1                 76.1                                    8
# 2                 73.5                                    8
# 3                 54.0                                    7
# 4                 50.9                                    7
# 5                 94.0                                    6
# 6                 84.9                                    6
# 7                 57.3                                    6
# 8                 81.3                                    6
# 9                 65.4                                    6
# 10                92.6                                    6
# 11                72.0                                    6
# 12                78.0                                    6
# 13                70.6                                    6
# 14                71.1                                    6
# 15                52.2                                    6
# 16                70.9                                    6
# 17                89.9                                    6
# 18                95.5                                    6
# 19                68.3                                    6

# %% [markdown]
# Analysis the relationship between average income, social classes and predominant industry

# %%
# %%bigquery
# select sum(Rich) as Total_Rich, sum(Upper_Middle) as Total_Upper_Middle, sum(Middle) as Total_Middle,
# avg(Average) as Average, Predominant_Industry_First, Predominant_Industry_Second, Predominant_Industry_Third
# from `acs_2018_modeled.Income_Beam_DF` i join `acs_2018_modeled.Labor_In_Industry_Beam_DF` l on i.ZCTA5 = l.ZCTA5
# where Predominant_Class = "Rich" or Predominant_Class = "Upper_Middle" or Predominant_Class = "Middle"
# group by Predominant_Industry_First,Predominant_Industry_Second, Predominant_Industry_Third
# having Predominant_Industry_First <> "" and Predominant_Industry_Second <> ""  and Predominant_Industry_Third <> ""
# order by Average desc
# limit 20
# Out:
#     Total_Rich  Total_Upper_Middle  Total_Middle  Average  \
# 0         43.3                 0.0          30.0  54.6240
# 1         26.8                60.1          41.8  39.6248
# 2         15.8                24.7          21.9  39.5720
# 3         13.8                36.2          11.5  38.8788
# 4          9.9                33.1          21.7  38.4720
# 5          0.0                48.3          17.2  37.5518
# 6          7.0                30.3          38.7  37.1590
# 7         12.5                16.6          33.3  37.0044
# 8         11.1                19.8          29.4  35.1084
# 9         21.3                74.7          99.5  34.1644
# 10         4.0                33.6          29.1  33.8092
# 11        11.1                18.5          30.5  33.5790
# 12         0.0                39.9          10.4  33.2342
# 13         7.7                25.6          27.2  32.8496
# 14        51.1                51.9          99.6  32.0311
# 15         8.4                21.0          26.0  31.7948
# 16         4.2                25.1          25.6  30.6694
# 17         6.8                20.3          26.8  30.3576
# 18        14.5                89.7         119.8  29.7960
# 19         8.7                46.0          60.9  29.6705
#
#             Predominant_Industry_First         Predominant_Industry_Second  \
# 0                          Information  Professional_Scientific_Management
# 1              Educational_Health_Care  Professional_Scientific_Management
# 2   Professional_Scientific_Management                              Retail
# 3                  Finance_Real_Estate                   Art_Entertainment
# 4   Professional_Scientific_Management               Public_Administration
# 5                        Manufacturing                      Transportation
# 6   Professional_Scientific_Management             Educational_Health_Care
# 7              Educational_Health_Care               Public_Administration
# 8   Professional_Scientific_Management                   Art_Entertainment
# 9              Educational_Health_Care  Professional_Scientific_Management
# 10                 Finance_Real_Estate                        Construction
# 11  Professional_Scientific_Management             Educational_Health_Care
# 12                        Construction             Educational_Health_Care
# 13                      Transportation             Educational_Health_Care
# 14             Educational_Health_Care                              Retail
# 15                         Agriculture                        Construction
# 16                        Construction  Professional_Scientific_Management
# 17                   Art_Entertainment                              Retail
# 18                         Agriculture             Educational_Health_Care
# 19             Educational_Health_Care               Public_Administration
#
#    Predominant_Industry_Third
# 0         Finance_Real_Estate
# 1         Finance_Real_Estate
# 2     Educational_Health_Care
# 3              Transportation
# 4     Educational_Health_Care
# 5           Art_Entertainment
# 6                Construction
# 7         Finance_Real_Estate
# 8       Public_Administration
# 9       Public_Administration
# 10    Educational_Health_Care
# 11        Finance_Real_Estate
# 12                  Wholesale
# 13                     Retail
# 14        Finance_Real_Estate
# 15    Educational_Health_Care
# 16              Manufacturing
# 17               Construction
# 18          Art_Entertainment
# 19               Construction

# %% [markdown]
# Analysis the relationship between working weeks per year, working hours per week and average income

# %%
# %%bigquery
# select Work_50_to_52_weeks, w.No_working as no_working_yearly, Work_35h_or_more, h.No_working as no_working_weekly, Average
# from `acs_2018_modeled.Working_Hours_Per_Week_Beam_DF` h
# left join `acs_2018_modeled.Working_Weeks_Per_Year_Beam_DF` w on h.ZCTA5 = w.ZCTA5
# left join `acs_2018_modeled.Income_Beam_DF` i on h.ZCTA5 = i.ZCTA5
# where Average <> 0
# order by Average desc
# limit 20
# Out:
#     Work_50_to_52_weeks  no_working_yearly  Work_35h_or_more  \
# 0                    88                  0                71
# 1                    26                  0                16
# 2                   187                 77               288
# 3                   293                 96               300
# 4                  2174                 21              2295
# 5                   155                  0               155
# 6                    13                 28                13
# 7                   180                 48               198
# 8                  6538               1648              7572
# 9                    81                 71                69
# 10                  107                 13               136
# 11                  168                 59                96
# 12                 6881               1647              7181
# 13                   11                 20                11
# 14                  618                138               576
# 15                 3165               3710              5353
# 16                   20                 14                17
# 17                   14                  2                16
# 18                  290                130               226
# 19                   37                  2                35
#
#     no_working_weekly  Average
# 0                   0  54.6240
# 1                   0  48.1170
# 2                  77  47.8570
# 3                  96  47.6912
# 4                  21  45.3122
# 5                   0  44.2394
# 6                  28  43.3324
# 7                  48  42.5184
# 8                1648  39.5720
# 9                  71  38.8788
# 10                 13  38.6754
# 11                 59  38.6196
# 12               1647  38.4720
# 13                 20  38.0172
# 14                138  37.9218
# 15               3710  37.5900
# 16                 14  37.5518
# 17                  2  37.4066
# 18                130  37.1590
# 19                  2  37.0680

# %% [markdown]
# Analysis total number of working from home and total number of working full week in different predominant industry

# %%
# %%bigquery
# select sum(Work_From_Home) as Total_Work_From_Home, sum(Work_35h_or_more) as Total_Full_Work_Week, Predominant_Industry_First, Predominant_Industry_Second, Predominant_Industry_Third
# from `acs_2018_modeled.Working_Hours_Per_Week_Beam_DF` h
# join  `acs_2018_modeled.Commute_Beam_DF` c on c.ZCTA5 = h.ZCTA5
# join  `acs_2018_modeled.Labor_In_Industry_Beam_DF` i on i.ZCTA5 = h.ZCTA5
# group by Predominant_Industry_First, Predominant_Industry_Second, Predominant_Industry_Third
# having Total_Full_Work_Week > 0
# order by Total_Full_Work_Week desc, Total_Work_From_Home desc
# limit 20
# Out:
#     Total_Work_From_Home  Total_Full_Work_Week  \
# 0                12143.5              14167197
# 1                 6620.5              10400016
# 2                 5136.1               8560159
# 3                 4436.5               6953362
# 4                 5526.0               6615709
# 5                 4182.7               6288411
# 6                 5312.0               5390499
# 7                 4516.5               5297865
# 8                 4989.8               4920260
# 9                 3679.4               4401166
# 10                3211.0               3794090
# 11                2799.4               3780247
# 12                2118.0               2138927
# 13                1983.2               1878111
# 14                2741.8               1618935
# 15                1223.4               1254830
# 16                3498.0               1171127
# 17                 951.8               1159501
# 18                1305.9               1147757
# 19                1132.4               1138809
#
#             Predominant_Industry_First         Predominant_Industry_Second  \
# 0              Educational_Health_Care                       Manufacturing
# 1              Educational_Health_Care  Professional_Scientific_Management
# 2              Educational_Health_Care                              Retail
# 3              Educational_Health_Care                              Retail
# 4              Educational_Health_Care                              Retail
# 5              Educational_Health_Care  Professional_Scientific_Management
# 6              Educational_Health_Care  Professional_Scientific_Management
# 7              Educational_Health_Care                   Art_Entertainment
# 8                        Manufacturing             Educational_Health_Care
# 9              Educational_Health_Care  Professional_Scientific_Management
# 10             Educational_Health_Care                       Manufacturing
# 11             Educational_Health_Care                   Art_Entertainment
# 12             Educational_Health_Care                       Manufacturing
# 13  Professional_Scientific_Management             Educational_Health_Care
# 14             Educational_Health_Care                              Retail
# 15             Educational_Health_Care                 Finance_Real_Estate
# 16             Educational_Health_Care                       Manufacturing
# 17             Educational_Health_Care  Professional_Scientific_Management
# 18             Educational_Health_Care                              Retail
# 19                   Art_Entertainment             Educational_Health_Care
#
#             Predominant_Industry_Third
# 0                               Retail
# 1                               Retail
# 2   Professional_Scientific_Management
# 3                    Art_Entertainment
# 4                        Manufacturing
# 5                    Art_Entertainment
# 6                  Finance_Real_Estate
# 7                               Retail
# 8                               Retail
# 9                        Manufacturing
# 10  Professional_Scientific_Management
# 11  Professional_Scientific_Management
# 12                   Art_Entertainment
# 13                 Finance_Real_Estate
# 14                        Construction
# 15  Professional_Scientific_Management
# 16                        Construction
# 17               Public_Administration
# 18               Public_Administration
# 19                              Retail

# %% [markdown]
# ## Create view

# %%
# %%bigquery
# create or replace view acs_2018_modeled.v_Industry_With_Higher_Income as
# select i.ZCTA5, sum(Rich) as Total_Rich, sum(Upper_Middle) as Total_Upper_Middle, sum(Middle) as Total_Middle,
# avg(Average) as Average, Predominant_Industry_First, Predominant_Industry_Second, Predominant_Industry_Third
# from `sashimi-266523.acs_2018_modeled.Income_Beam_DF` i
# join `sashimi-266523.acs_2018_modeled.Labor_In_Industry_Beam_DF` l on i.ZCTA5 = l.ZCTA5
# where Predominant_Class = "Rich" or Predominant_Class = "Upper_Middle" or Predominant_Class = "Middle"
# group by i.ZCTA5, Predominant_Industry_First,Predominant_Industry_Second, Predominant_Industry_Third
# having Predominant_Industry_First <> "" and Predominant_Industry_Second <> ""  and Predominant_Industry_Third <> ""
# order by Average desc
# Out:
# Empty DataFrame
# Columns: []
# Index: []
